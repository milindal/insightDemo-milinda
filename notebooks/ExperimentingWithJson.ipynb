# %%
from urllib2 import Request, urlopen, URLError
import numpy as np 
import json 
import pandas as pd 
import matplotlib.pyplot as plt 
import gensim as gs
import nltk
from sklearn.cluster import KMeans
import pickle
import string 
import re
# %matplotlib inline

# %%
database_dict = pickle.load(open('data/updated_database_dict.p', 'rb'))

# %%
print len(database_dict)
# Out:
# 17

# %%
json.dump(database_dict, open('data/database_dict.josn', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1a025de10666> in <module>()
# ----> 1 json.dump(database_dict, open('data/database_dict.josn', 'wb'))
#
# /Users/milindal/anaconda/lib/python2.7/json/__init__.pyc in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     187     # could accelerate with writelines in some versions of Python, at
#     188     # a debuggability cost
# --> 189     for chunk in iterable:
#     190         fp.write(chunk)
#     191
#
# /Users/milindal/anaconda/lib/python2.7/json/encoder.pyc in _iterencode(o, _current_indent_level)
#     432                 yield chunk
#     433         elif isinstance(o, dict):
# --> 434             for chunk in _iterencode_dict(o, _current_indent_level):
#     435                 yield chunk
#     436         else:
#
# ...
