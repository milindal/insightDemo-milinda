# %%
from __future__ import division
import operator
import nltk
import string

def isPunct(word):
  return len(word) == 1 and word in string.punctuation

def isNumeric(word):
  try:
    float(word) if '.' in word else int(word)
    return True
  except ValueError:
    return False

class RakeKeywordExtractor:

  def __init__(self):
    self.stopwords = set(nltk.corpus.stopwords.words())
    self.top_fraction = 1 # consider top third candidate keywords by score

  def _generate_candidate_keywords(self, sentences):
    phrase_list = []
    for sentence in sentences:
      words = map(lambda x: "|" if x in self.stopwords else x,
        nltk.word_tokenize(sentence.lower()))
      phrase = []
      for word in words:
        if word == "|" or isPunct(word):
          if len(phrase) > 0:
            phrase_list.append(phrase)
            phrase = []
        else:
          phrase.append(word)
    return phrase_list

  def _calculate_word_scores(self, phrase_list):
    word_freq = nltk.FreqDist()
    word_degree = nltk.FreqDist()
    for phrase in phrase_list:
      degree = len(filter(lambda x: not isNumeric(x), phrase)) - 1
      for word in phrase:
        word_freq[word] += 1
        word_degree[word] +=  degree # other words
    for word in word_freq.keys():
      word_degree[word] = word_degree[word] + word_freq[word] # itself
    # word score = deg(w) / freq(w)
    word_scores = {}
    for word in word_freq.keys():
      word_scores[word] = word_degree[word] / word_freq[word]
    return word_scores

  def _calculate_phrase_scores(self, phrase_list, word_scores):
    phrase_scores = {}
    for phrase in phrase_list:
      phrase_score = 0
      for word in phrase:
        phrase_score += word_scores[word]
      phrase_scores[" ".join(phrase)] = phrase_score
    return phrase_scores
    
  def extract(self, text, incl_scores=False):
    sentences = nltk.sent_tokenize(text)
    phrase_list = self._generate_candidate_keywords(sentences)
    word_scores = self._calculate_word_scores(phrase_list)
    phrase_scores = self._calculate_phrase_scores(
      phrase_list, word_scores)
    sorted_phrase_scores = sorted(phrase_scores.iteritems(),
      key=operator.itemgetter(1), reverse=True)
    n_phrases = len(sorted_phrase_scores)
    if incl_scores:
      return sorted_phrase_scores[0:int(n_phrases/self.top_fraction)]
    else:
      return map(lambda x: x[0],
        sorted_phrase_scores[0:int(n_phrases/self.top_fraction)])

# %%
from urllib2 import Request, urlopen, URLError
import numpy as np 
import json 
import pandas as pd 
import matplotlib.pyplot as plt 
import gensim as gs
import nltk
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import pickle
import string 
import re
# %matplotlib inline

# %%
# helper functions to clean the data
def striphtml(data):
    p = re.compile(r'<.*?>')
    return p.sub('', data)

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english')).union(set(['``', "''", '.', ',', '!', ':', '[', ']', '...', "\'\'" , '']))

# Stemming words (or not?)
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
database_dict = pickle.load(open('data/updated_database_dict.p', 'rb'))

# %%
# Get the url list
urls_list = [line.rstrip('\n') for line in open('../insightDemo-milinda/data/URLStest.txt').readlines() if len(line) > 5] 
urls_list
# Out:
# ['http://www.nytimes.com/2015/09/11/us/politics/iran-nuclear-deal-senate.html',
#  'http://www.nytimes.com/2015/09/12/health/blood-pressure-study.html',
#  'http://www.nytimes.com/2012/06/26/us/supreme-court-rejects-part-of-arizona-immigration-law.html',
#  'http://www.nytimes.com/2015/06/15/opinion/workers-betrayed-by-visa-loopholes.html',
#  'http://www.nytimes.com/2015/09/15/world/europe/europe-migrants-germany.html',
#  'http://www.nytimes.com/2015/07/22/opinion/the-campaign-of-deception-against-planned-parenthood.html',
#  'http://www.nytimes.com/2015/06/05/opinion/edward-snowden-the-world-says-no-to-surveillance.html',
#  'http://www.nytimes.com/2015/09/20/opinion/sunday/a-toxic-work-world.html',
#  'http://www.nytimes.com/2015/08/16/technology/inside-amazon-wrestling-big-ideas-in-a-bruising-workplace.html']

# %%
url_string = urls_list[-2]
print url_string 

# Get the three most diverse trusted comments assosciated with the url string
comments_df = database_dict[url_string]['comments_df']
comment_bodies = comments_df['commentBody']

# round 1: tokenizing, stemming, removing html tags and stop words
comment_texts = [[ps.stem(filter(lambda x: x in string.printable, word).lower()) for word in nltk.word_tokenize(striphtml(comment)) 
              if word not in stop_words] for comment in comment_bodies]
#     print len(comment_texts)

# round 2: filtering, remove words from comments that are too short or which are not alphabets
comment_texts = [ [word for word in comment if (len(word) > 2 and not word.isdigit()and word not in stop_words)] for comment in comment_texts]
#     print comment_texts[0:5]

# create a dictionary for the words that appear in the comments 
dictionary = gs.corpora.Dictionary(comment_texts)

# Bag of words representation for the comments 
comment_corpus = [dictionary.doc2bow(text) for text in comment_texts]

# Train tf-idf model on the comment_corpus
tfidf = gs.models.TfidfModel(comment_corpus)
corpus_tfidf = tfidf[comment_corpus]

# initialize an LSI transformation
lsi = gs.models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=1000) 
corpus_lsi = lsi[corpus_tfidf] # create a double wrapper over the original corpus: bow->tfidf->fold-in-lsi
#     lsi.print_topics(5)
# Out:
# http://www.nytimes.com/2015/09/20/opinion/sunday/a-toxic-work-world.html

# %%
# Create the coordinates for the corpus to send into the Kmeans clustering algorithm
comments_coords_lsi_ND = [] 
N_dimensions = 10
for item in corpus_lsi: 
    coord_temp = [0]*N_dimensions
    for val_tuple in item:
        if val_tuple[0] < N_dimensions: 
            coord_temp[val_tuple[0]] = val_tuple[1]
    comments_coords_lsi_ND.append(coord_temp)

# %%
k_fixed = 3
kmeans = KMeans(k_fixed).fit(np.array(comments_coords_lsi_ND))

# %%
lab = 0 
comment_bodies_lab = comments_df.loc[kmeans.labels_ == lab, 'commentBody']
print comment_bodies_lab.shape
# print striphtml(comment_bodies_lab[0])
all_comments_text = ''
for comment in comment_bodies_lab: 
    all_comments_text += striphtml(comment) + ' ' 
rake = RakeKeywordExtractor()
keywords = rake.extract(all_comments_text, incl_scores=True)
print keywords
# Out:
# (244,)
# [(u'elements mutually complement one another.our artificial bubble', 36.766666666666666), (u"`` welfare '' stories cover `` low income working mothers", 36.32479604265153), (u'mr. severgnini thinks americans could ever learn anything', 35.91117424242424), (u"leave plus 10'additional weeks fmla maternity leave", 35.20975609756098), (u"thoughtless owners.the economic collapse `` recession ''", 34.20633670791151), (u"head start 's family centered policies enables families", 32.26024227234754), (u'high productivity levels producing high quality work.i think', 30.69736842105263), (u'saw many 40-50 year old family earners replaced', 29.166690310682366), (u'good paying middle class manufacturing jobs overseas.if', 27.637228260869566), (u'build business via developing 7 figure+ deals', 26.386363636363637), (u"`` spectrum adult day health program ''", 26.37300337457818), (u"economists count `` household formation ''", 26.039670041244847), (u"'s really ridiculous given available technology.some weeks", 25.666666666666664), (u"dramatically new paradigm.the `` epidemic ''", 25.58133670791151), (u'american middle class.modern american work forces need', 24.70868049826761), (u"music cd `` fellow workers ''", 24.666336707911515), (u"`` data-driven '' consulting firm refused", 24.48411448568929), (u"constantly growing `` aggregate demand ''", 24.414670041244847), (u'class featuring cosmologist brian swimme', 23.0), (u'people spend untold hours creating presentations', 22.53503787878788), (u"`` affordable high quality child care ''", 22.50642435652539), (u'inherited contradictory impulses make us human', 22.351956554084214), (u'over-working everyone -- singles without children', 22.273928707638664), (u'21st century -- leaving every individual', 22.242559523809522), (u'columbia alongside little george stephanopolous', 22.09090909090909), (u'geared towards rewarding short-term investments', 21.5), (u'recent supreme court decisions companies', 21.416666666666668), (u"`` high quality child care '' means", 21.183347433448468), (u'every employee would receive twelve weeks', 21.102358490566036), (u'problems arise whenever anyone -- male', 21.09375), (u'12-16 hour days without additional compensation', 20.910233918128654), (u"`` 100 slide power points ''", 20.573003374578178), (u'children whose aging parents need appropriate care', 20.41122475292034), (u"2015beppe severgniniit 's really cute", 20.166666666666664), (u"`` cost-benefit analysis '' applied", 20.039670041244847), (u"euphemistically called `` associates ''", 20.039670041244847), (u'\u201cthe firm\u2019s key human resources problem', 19.654595404595405), (u'always warned social security would become', 19.628992477494144), (u'non-unionised corporations call virtually every worker', 19.618761140819966), (u'one may find alternative starting points', 19.573636363636364), (u"`` fixing '' anything chances", 19.573003374578178), (u'someone like governor scott walker', 19.356312292358805), (u'labor onto whichever spouse earns', 19.064655172413794), (u'falling fuel prices airlines responded', 18.833333333333332), (u"wonderful so-called `` productivity ''", 18.789670041244847), (u'half heartedly acknowledged global warming', 18.566666666666666), (u'child care centers often lost workers', 18.35307010475423), (u"princeton 's woodrow wilson school", 18.305555555555557), (u"`` slave worker '' paradigm", 18.24555239418602), (u'federally funded head start program', 18.073809523809523), (u'\u201cdiscriminated\u201d childfree individuals may comprehend', 18.026666666666664), (u'`` americans apply less physical effort', 17.969913361143337), (u"`` constant quantitative growth ''", 17.827548829123636), (u'tthe picture seems quite clear', 17.816666666666666), (u'provides 2 weeks paid maternity', 17.355172413793102), (u'driver less trucks put millions', 17.313793103448276), (u'united states labor unions could help balance', 17.301262315270936), (u"world 's economic pie smaller", 17.292397660818715), (u'another low ...

# %%
import sys 
sys.path.insert(0, '/Users/milindal/Dropbox/Insight/rake_experiments/RAKE-tutorial')
import rake 
import operator

# %%
rake_object = rake.Rake("/Users/milindal/Dropbox/Insight/rake_experiments/RAKE-tutorial/SmartStoplist.txt", 5, 3, 4)

# %%
for lab in range(3):
    comment_bodies_lab = comments_df.loc[kmeans.labels_ == lab, 'commentBody']
    print comment_bodies_lab.shape
    # print striphtml(comment_bodies_lab[0])
    all_comments_text = ''
    for comment in comment_bodies_lab: 
        all_comments_text += striphtml(comment) + ' ' 
    keywords = rake_object.run(all_comments_text)
    print "Keywords:", keywords
# Out:
# (244,)
# Keywords:
#  [(u'child care', 4.567032967032967), (u'paid time', 4.52), (u'work world', 4.225225225225225), (u'human beings', 4.128571428571429), (u'life balance', 4.102639296187683), (u'work harder', 4.083333333333334), (u'bernie sanders', 4.011111111111111), (u'corporate america', 3.9785714285714286), (u'labor force', 3.9655172413793105), (u'vast majority', 3.9142857142857146), (u'american workers', 3.7922330097087382), (u'bottom line', 3.6666666666666665), (u'small businesses', 3.6013986013986017), (u'working people', 3.5954716981132075), (u'human resources', 3.383116883116883), (u'conditions', 2.0952380952380953), (u'working', 2.0754716981132075), (u'child', 2.0285714285714285), (u'quality', 2.0